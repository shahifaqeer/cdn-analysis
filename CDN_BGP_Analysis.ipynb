# %% [markdown]
# # ASN and CDN lookup
# - Use ipasn library to download latest routeviews data and lookup ASN for particular IP
# - other options include cymru queries (no dependency use command line)

# %%
from __future__ import division
# %pylab inline
import pandas as pd
import numpy as np
import subprocess
import os, sys, re
from collections import defaultdict
import socket
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_sites = pd.read_csv('top-1m-new.csv', nrows=500, header = None, names = ['rank', 'site'])

# %%
def getIP(s):
    try:
        IP = socket.gethostbyname(s)
        # blocked domains return IP 49.207.46.6, 49.207.46.24, 49.207.46.34 from ISP
        if IP in ['49.207.46.6', '49.207.46.24', '49.207.46.34']:
            print("Blocked site "+s)
            return False
        else:
            return IP
    except:
        print("Error accessing site "+s)
        return False

df_sites['IP'] = df_sites['site'].apply(getIP)
# Out:
# Blocked site pornhub.com
# Blocked site ok.ru
# Blocked site livejasmin.com
# Blocked site xvideos.com
# Error accessing site googleusercontent.com
# Blocked site xhamster.com
# Error accessing site exosrv.com
# Blocked site xnxx.com
# Blocked site chaturbate.com
# Blocked site yts.am
# Blocked site youporn.com
# Blocked site 1337x.to
# Error accessing site cloudfront.net
# Blocked site redtube.com
# Blocked site rutracker.org
# Error accessing site banvenez.com
# Error accessing site bp.blogspot.com
# Error accessing site exdynsrv.com
# Blocked site sex.com
# Error accessing site wixsite.com

# %%
df_sites.head()
# Out:
#    rank           site               IP
# 0     1     google.com    216.58.221.46
# 1     2    youtube.com   172.217.167.46
# 2     3   facebook.com    157.240.25.35
# 3     4      baidu.com  123.125.115.110
# 4     5  wikipedia.org  103.102.166.224

# %%
import pyasn

asndb = pyasn.pyasn('output/ipasn_20181212.dat')  #downloaded pyasn_util_download.py --latest
asndb.lookup('8.8.8.8')
# Out:
# (15169, '8.8.8.0/24')

# %%
def findASN(ip):
    if ip:
        return asndb.lookup(ip)[0]
    else:
        return False
    
df_sites['ASN'] = df_sites['IP'].apply(findASN)

# %%
df_sites.head()
# Out:
#    rank           site               IP    ASN
# 0     1     google.com    216.58.221.46  15169
# 1     2    youtube.com   172.217.167.46  15169
# 2     3   facebook.com    157.240.25.35  32934
# 3     4      baidu.com  123.125.115.110   4808
# 4     5  wikipedia.org  103.102.166.224  14907

# %%
df_valid = df_sites[df_sites['IP'] != False]

# %%
len(df_valid)
# Out:
# 480

# %% [markdown]
# ## CDN finder
# - use whois queries to find Organization names and emails as they are related to CDNs

# %%
def findOrg(site_IP):
    # use whois <IPADDR> to find and parse the organization and email server of site_IP
    # return dict {Org, OrgName, Email}
    
    Org = []
    OrgKeywords = ['organisation:', 'org:', 'organization:', 'org-name:', 'orgname:']
    Email = []
    EmailKeywords = ['@', 'email:', 'mailbox:', 'e-mail:']
    exclude_orgs = ['AFRINIC','APNIC','ARIN','LACNIC','IANA',
                    'Asia Pacific Network Information Centre', 'Administered by RIPE NCC', 'RIPE NCC']
    
    try:
        out2 = subprocess.check_output(['whois', site_IP], stderr=subprocess.STDOUT,
                                       timeout=10.0).decode('UTF-8', 'ignore')

        for line in out2.split('\n'):
            lower_line = line.lower()

            for keyword in OrgKeywords:
                if keyword in lower_line:
                    if not any([excl_org in line for excl_org in exclude_orgs]):
                        org = line.split(':')[1].strip()
                        if not org in Org:
                            Org.append(org)

            for keyword in EmailKeywords:
                if keyword in lower_line:
                    email = line.split('@')[1].strip()
                    if not email in Email:
                        Email.append(email)
            #print(line)
    
    except:
        print('whois '+site_IP+' process error/ran too long')

    output = {'Org': Org, 'Email': Email }
    
    return output

# %%
#sites_org = df_valid['IP'].apply(lambda s: pd.Series( findOrg(s) ) )
#sites_org.to_pickle('output/df_org_email_info.pkl')

# %%
sites_org = pd.read_pickle('output/df_org_email_info.pkl')

# %% [markdown]
# ### Merge CDN org info with ASN and IP info

# %%
sites_cdn = df_valid.merge(sites_org, left_index=True, right_index=True )

# %%
sites_cdn.head()
# Out:
#    rank           site               IP    ASN  \
# 0     1     google.com    216.58.221.46  15169
# 1     2    youtube.com   172.217.167.46  15169
# 2     3   facebook.com    157.240.25.35  32934
# 3     4      baidu.com  123.125.115.110   4808
# 4     5  wikipedia.org  103.102.166.224  14907
#
#                                           Org  \
# 0             [Google LLC (GOGL), Google LLC]
# 1             [Google LLC (GOGL), Google LLC]
# 2  [Facebook, Inc. (THEFA-3), Facebook, Inc.]
# 3                                          []
# 4   [ORG-WFI1-AP, Wikimedia Foundation, Inc.]
#
#                                                Email  numOrg  numEmail
# 0                                       [google.com]       2         1
# 1                                       [google.com]       2         1
# 2                                           [fb.com]       2         1
# 3  [ns.chinanet.cn.net', ns.chinanet.cn.net, bjte...       0         3
# 4                    [wikimedia.org', wikimedia.org]       2         2

# %%
sites_cdn['numOrg'] = sites_cdn['Org'].apply(len)
sites_cdn['numEmail'] = sites_cdn['Email'].apply(len)

# %% [markdown]
# #### Check if there are valid IPs with no available data in email servers and organization names fields

# %%
sites_cdn[sites_cdn['numEmail']==0]
# Out:
# Empty DataFrame
# Columns: [rank, site, IP, ASN, Org, Email, numOrg, numEmail]
# Index: []

# %%
sites_cdn
# Out:
#      rank              site               IP     ASN  \
# 0       1        google.com    216.58.221.46   15169
# 1       2       youtube.com   172.217.167.46   15169
# 2       3      facebook.com    157.240.25.35   32934
# 3       4         baidu.com  123.125.115.110    4808
# 4       5     wikipedia.org  103.102.166.224   14907
# 5       6            qq.com    111.161.64.40    4837
# 6       7         yahoo.com     98.137.246.8   36647
# 7       8        amazon.com   176.32.103.205   16509
# 8       9        taobao.com   140.205.220.96   37963
# 9      10        reddit.com    151.101.1.140   54113
# 10     11         tmall.com   140.205.130.99   37963
# 11     12      google.co.in   216.58.196.195   15169
# 12     13       twitter.com     104.244.42.1   13414
# 13     14          live.com   204.79.197.212    8068
# 14     15          sohu.com   123.125.116.28    4808
# 15     16            jd.com   120.52.148.118  133119
# 16     17         yandex.ru     5.255.255.70   13238
# 17     18      google.co.jp  172.217.166.227   15169
# 18     19     instagram.com     35.169.78.50   14618
# 19     20         weibo.com   114.134.80.162    9304
# 20     21       sina.com.cn   202.108.33.107    4808
# 21     22            360.cn    36.110.213.49   23724
# 22     23   login.tmall.com   223.30.211.253    9583
# 23     24      blogspot.com   172.217.167.41   15169
# 24     25     google.com.hk   216.58.196.195   15169
# 25     26      linkedin.com    108.174.10.10   14413
# 26     27       netflix.com    52.50.212.245   16509
# 27     28     google.com.br    172.217.161.3   15169
# 28     29       yahoo.co.jp   183.79.135.206   24572
# 29     30        office.com    52.108.240.70    8075
# ..    ...               ...              ...     ...
# 469   470          egy.best    104.25.237.22   13335
# 470   471  surveymonkey.com     64.191.16.50   18915
# 471   472   playstation.com  209.200.152.198   32787
# 472   473          9gag.com  151.101.194.133   54113
# 473   474     google.com.kw  172.217.166.227   15169
# 474   475     crptentry.com     93.93.53.190   34655
# 475   476      usatoday.com   159.54.242.176   21735
# 476   477      theverge.com     151.101.1.52   54113
# 477   478         seznam.cz      77.75.77.39   43037
# 478   479          rarbg.to   185.37.100.122  200097
# 479   480        rediff.com     23.67.216.77   16625
# 480   481           grid.id     52.77.11.251   38895
# 481   482        kooora.com   107.154.103.19   19551
# 482   483      dcinside.com    221.143.22.47    9318
# 483   484      kissanime.ru     104.20.27.43   13335
# 485   486       mawdoo3.com   151.101.66.202   54113
# 486   487          ieee.org   140.98.193.152   13462
# 487   488       android.com  172.217.166.196   15169
# 488   489         smzdm.com    106.75.63.226    4808
# 489   490      ilovepdf.com      104.20.1.94   13335
# 490   491          citi.com   192.193.218.80   32287
# 491   492       ebay.com.au    66.211.185.77   11643
# 492   493    digitaldsp.com   188.42.162.140   35415
# 493   494         webmd.com    208.93.170.15   46244
# 494   495          oath.com   212.82.100.153   34010
# 495   496    jf71qh5v14.com  198.134.112.243   27257
# 496   497          souq.com    34.254.80.156   16509
# 497   498    biobiochile.cl      67.43.7.192   32244
# 498   499       merdeka.com        103.6.0.3   58497
# 499   500           adp.com    170.146.93.56   14299
#
#                                                    Org  \
# 0                      [Google LLC (GOGL), Google LLC]
# 1                      [Google LLC (GOGL), Google LLC]
# 2           [Facebook, Inc. (THEFA-3), Facebook, Inc.]
# 3                                                   []
# 4            [ORG-WFI1-AP, Wikimedia Foundation, Inc.]
# 5                                                   []
# 6                    [Yahoo! Inc. (YHOO), Yahoo! Inc.]
# 7      [Amazon.com, Inc. (AMAZON-4), Amazon.com, Inc.]
# 8                                                   []
# 9                           [Fastly (SKYCA-3), Fastly]
# 10                                                  []
# 11                     [Google LLC (GOGL), Google LLC]
# 12                [Twitter Inc. (TWITT), Twitter Inc.]
# 13   [Microsoft Corporation (MSFT), Microsoft Corpo...
# 14                                                  []
# 15                                                  []
# 16                                                  []
# 17                     [Google LLC (GOGL), Google LLC]
# 18   [Amazon Technologies Inc. (AT-88-Z), Amazon Te...
# 19                                                  []
# 20                                                  []
# 21                                                  []
# 22                                                  []
# 23                     [Google LLC (GOGL), Google LLC]
# 24                     [Google LLC (GOGL), Google LLC]
# 25   [LinkedIn Corporation (LINKE-1), LinkedIn Corp...
# 26   [Amazon Technologies Inc. (AT-88-Z), Amazon Te...
# 27                     [Google LLC (GOGL), Google LLC]
# 28                                                  []
# 29   [Microsoft Corporation (MSFT), Microsoft Corpo...
# ..                                                 ...
# 469     [Cloudflare, Inc. (CLOUD14), Cloudflare, Inc.]
# 470   [SurveyMonkey Inc. (SURVE-7), SurveyMonkey Inc.]
# 471  [Akamai Technologies, Inc. (AKAMAI), Akamai Te...
# 472                         [Fastly (SKYCA-3), Fastly]
# 473                    [Google LLC (GOGL), Google LLC]
# 474                                                 []
# 475  [Gannett Satellite Information Network, LLC. (...
# 476                         [Fastly (SKYCA-3), Fastly]
# 477                                                 []
# 478      [ORG-SAAA2-RIPE, S A and A stroi proekt EOOD]
# 479  [Akamai Technologies, Inc. (AKAMAI), Akamai Te...
# 480  [Amazon Technologies Inc. (AT-88-Z), Amazon Te...
# 481           [Incapsula Inc (INCAP-5), Incapsula Inc]
# 482                                                 []
# 483     [Cloudflare, Inc. (CLOUD14), Cloudflare, Inc.]
# 485                         [Fastly (SKYCA-3), Fastly]
# 486  [Institute of Electrical and Electronics Engin...
# 487                    [Google LLC (GOGL), Google LLC]
# 488                                                 []
# 489     [Cloudflare, Inc. (CLOUD14), Cloudflare, Inc.]
# 490  [Citicorp Global Information Network (CGIN), C...
# 491                      [eBay, Inc (EBAY), eBay, Inc]
# 492                                                 []
# 493                 [WebMD, Inc. (WEBMD), WebMD, Inc.]
# 494  [Inktomi Corporation (INKT), Inktomi Corporation]
# 495  [Webair Internet Development Company Inc. (WAI...
# 496  [Amazon Data Services Ireland Limited (ADSIL-1...
# 497      [Liquid Web, L.L.C (LQWB), Liquid Web, L.L.C]
# 498                                                 []
# 499  [Automatic Data Processing, Inc. (ADPES), Auto...
#
#                                                  Email  numOrg  numEmail
# 0                                         [google.com]       2         1
# 1                                         [google.com]       2         1
# 2                                             [fb.com]       2         1
# 3    [ns.chinanet.cn.net', ns.chinanet.cn.net, bjte...       0         3
# 4                      [wikimedia.org', wikimedia.org]       2         2
# 5                    [chinaunicom.cn', chinaunicom.cn]       0         2
# 6                    [yahoo-inc.com, cc.yahoo-inc.com]       2         2
# 7                          [amazon.com, amazonaws.com]       2         2
# 8    [apnic.net, cnnic.cn', cnnic.cn, alibaba-inc.c...       0         6
# 9                                         [fastly.com]       2         1
# 10   [apnic.net, cnnic.cn', cnnic.cn, alibaba-inc.c...       0         6
# 11                                        [google.com]       2         1
# 12                                       [twitter.com]       2         1
# 13                     [microsoft.com., microsoft.com]       2         2
# 14   [chinaunicom.cn', chinaunicom.cn, publicf.bta....       0         3
# 15               [cnnic.cn', cnnic.cn, chinaunicom.cn]       0         3
# 16                 [yandex.ru', yandex.net, yandex.ru]       0         3
# 17                                        [google.com]       2         1
# 18                         [amazon.com, amazonaws.com]       2         2
# 19                           [hgc.com.hk', hgc.com.hk]       0         2
# 20   [chinaunicom.cn', chinaunicom.cn, publicf.bta....       0         3
# 21   [ns.chinanet.cn.net', bjtelecom.net, ns.chinan...       0         3
# 22                       [sifycorp.com', sifycorp.com]       0         2
# 23                                        [google.com]       2         1
# 24                                        [google.com]       2         1
# 25                                      [linkedin.com]       2         1
# 26                         [amazonaws.com, amazon.com]       4         2
# 27                                        [google.com]       2         1
# 28           [nic.ad.jp', mail.yahoo.co.jp, nic.ad.jp]       0         3
# 29                     [microsoft.com., microsoft.com]       2         2
# ..                                                 ...     ...       ...
# 469                                   [cloudflare.com]       2         1
# 470                                 [surveymonkey.com]       2         1
# 471                                       [akamai.com]       2         1
# 472                                       [fastly.com]       2         1
# 473                                       [google.com]       2         1
# 474                [duodecadits.com', duodecadits.com]       0         2
# 475                                      [gannett.com]       2         1
# 476                                       [fastly.com]       2         1
# 477                            [seznam.cz', seznam.cz]       0         2
# 478                   [netsaap.com', netsaap.com only]       2         2
# 479                                       [akamai.com]       2         1
# 480                        [amazonaws.com, amazon.com]       2         2
# 481                       [imperva.com, incapsula.com]       2         2
# 482           [nic.or.kr', nic.or.kr, skbroadband.com]       0         3
# 483                                   [cloudflare.com]       2         1
# 485                                       [fastly.com]       2         1
# 486                                         [ieee.org]       2         1
# 487                                       [google.com]       2         1
# 488                    [cnnic.cn', cnnic.cn, uclud.cn]       0         3
# 489                                   [cloudflare.com]       2         1
# 490                       [citi.com, cto.citicorp.com]       2         2
# 491                                         [ebay.com]       2         1
# 492                       [as5577.net', webzilla.com"]       0         2
# 493                                        [webmd.net]       2         1
# 494                  [yahoo-inc.com, cc.yahoo-inc.com]       2         2
# 495                                       [webair.com]       2         1
# 496                        [amazonaws.com, amazon.com]       4         2
# 497                                    [liquidweb.com]       2         1
# 498                        [merdeka.com', merdeka.com]       0         2
# 499                                          [adp.com]       2         1
#
# [480 rows x 8 columns]

# %% [markdown]
# ## Match CDN name with sites_cdn['Org']

# %%
with open('CDNnames.csv', 'r') as f:
    CDN_names = f.read().splitlines()

# %%
def matchCDN(org_list):
    if len(org_list)>0:
        for org in org_list:
            org_lower = org.lower()
            for cdn in CDN_names:
                cdn_lower = cdn.lower()
                if (cdn_lower in org_lower):
                    return cdn
                
    else:
        return None

# %%
sites_cdn['CDN'] = sites_cdn['Org'].apply(matchCDN)

# %%
sites_cdn[(sites_cdn['CDN'].isnull())]
# Out:
#      rank                 site               IP     ASN  \
# 2       3         facebook.com    157.240.25.35   32934
# 3       4            baidu.com  123.125.115.110    4808
# 4       5        wikipedia.org  103.102.166.224   14907
# 5       6               qq.com    111.161.64.40    4837
# 6       7            yahoo.com     98.137.246.8   36647
# 8       9           taobao.com   140.205.220.96   37963
# 10     11            tmall.com   140.205.130.99   37963
# 12     13          twitter.com     104.244.42.1   13414
# 13     14             live.com   204.79.197.212    8068
# 14     15             sohu.com   123.125.116.28    4808
# 15     16               jd.com   120.52.148.118  133119
# 16     17            yandex.ru     5.255.255.70   13238
# 19     20            weibo.com   114.134.80.162    9304
# 20     21          sina.com.cn   202.108.33.107    4808
# 21     22               360.cn    36.110.213.49   23724
# 22     23      login.tmall.com   223.30.211.253    9583
# 25     26         linkedin.com    108.174.10.10   14413
# 28     29          yahoo.co.jp   183.79.135.206   24572
# 29     30           office.com    52.108.240.70    8075
# 30     31  microsoftonline.com    40.84.199.233    8075
# 32     33             csdn.net    47.95.164.112   37963
# 33     34               vk.com   87.240.180.136   47541
# 36     37              mail.ru   94.100.180.201   47764
# 38     39      pages.tmall.com   223.30.211.253    9583
# 41     42           alipay.com     110.75.139.5   37963
# 42     43        microsoft.com   40.113.200.201    8075
# 45     46         whatsapp.com  192.155.212.202   36351
# 46     47                 t.co   104.244.42.133   13414
# 47     48             ebay.com    66.135.209.52   11643
# 50     51            naver.com    210.89.160.88   23576
# ..    ...                  ...              ...     ...
# 446   447             divar.ir   79.175.141.111   25184
# 450   451          okezone.com   202.80.220.208   23946
# 451   452        investing.com    185.94.84.100   56647
# 452   453              free.fr     212.27.48.10   12322
# 453   454   huffingtonpost.com     74.6.136.153   26101
# 457   458            yandex.kz      5.255.255.5   13238
# 458   459         seasonvar.ru   178.236.137.57   42775
# 460   461            goo.ne.jp   153.254.147.65    2914
# 461   462            marca.com   193.110.128.82    9052
# 463   464            bitly.com    67.199.248.14  395224
# 464   465             nike.com   146.197.184.71   54535
# 465   466        bloomberg.com   69.191.252.148   10361
# 466   467             cnbc.com   144.121.138.33   46887
# 467   468            libero.it   213.209.17.209    8660
# 468   469             duba.com    119.29.42.130   45090
# 470   471     surveymonkey.com     64.191.16.50   18915
# 474   475        crptentry.com     93.93.53.190   34655
# 475   476         usatoday.com   159.54.242.176   21735
# 477   478            seznam.cz      77.75.77.39   43037
# 482   483         dcinside.com    221.143.22.47    9318
# 486   487             ieee.org   140.98.193.152   13462
# 488   489            smzdm.com    106.75.63.226    4808
# 490   491             citi.com   192.193.218.80   32287
# 491   492          ebay.com.au    66.211.185.77   11643
# 492   493       digitaldsp.com   188.42.162.140   35415
# 493   494            webmd.com    208.93.170.15   46244
# 495   496       jf71qh5v14.com  198.134.112.243   27257
# 497   498       biobiochile.cl      67.43.7.192   32244
# 498   499          merdeka.com        103.6.0.3   58497
# 499   500              adp.com    170.146.93.56   14299
#
#                                                    Org  \
# 2           [Facebook, Inc. (THEFA-3), Facebook, Inc.]
# 3                                                   []
# 4            [ORG-WFI1-AP, Wikimedia Foundation, Inc.]
# 5                                                   []
# 6                    [Yahoo! Inc. (YHOO), Yahoo! Inc.]
# 8                                                   []
# 10                                                  []
# 12                [Twitter Inc. (TWITT), Twitter Inc.]
# 13   [Microsoft Corporation (MSFT), Microsoft Corpo...
# 14                                                  []
# 15                                                  []
# 16                                                  []
# 19                                                  []
# 20                                                  []
# 21                                                  []
# 22                                                  []
# 25   [LinkedIn Corporation (LINKE-1), LinkedIn Corp...
# 28                                                  []
# 29   [Microsoft Corporation (MSFT), Microsoft Corpo...
# 30   [Microsoft Corporation (MSFT), Microsoft Corpo...
# 32                                                  []
# 33                                                  []
# 36                                                  []
# 38                                                  []
# 41                                                  []
# 42   [Microsoft Corporation (MSFT), Microsoft Corpo...
# 45   [RIPE Network Coordination Centre (RIPE), RIPE...
# 46                [Twitter Inc. (TWITT), Twitter Inc.]
# 47                       [eBay, Inc (EBAY), eBay, Inc]
# 50                                                  []
# ..                                                 ...
# 446                                                 []
# 450                                                 []
# 451                                                 []
# 452                                                 []
# 453                            [ORG-YA6-AP, Yahoo-Inc]
# 457                                                 []
# 458                                                 []
# 460                                                 []
# 461  [ORG-UE2-RIPE, ORG-GATI1-RIPE, Unidad Editoria...
# 463                     [Bitly Inc (BITLY), Bitly Inc]
# 464                [Nike, Inc. (NIKEIN-1), Nike, Inc.]
# 465  [Bloomberg Financial Market (BFM-3), Bloomberg...
# 466  [Lightower Fiber Networks I, LLC (LFNIL), Ligh...
# 467                [ORG-MS8-RIPE, Italiaonline S.p.A.]
# 468                                                 []
# 470   [SurveyMonkey Inc. (SURVE-7), SurveyMonkey Inc.]
# 474                                                 []
# 475  [Gannett Satellite Information Network, LLC. (...
# 477                                                 []
# 482                                                 []
# 486  [Institute of Electrical and Electronics Engin...
# 488                                                 []
# 490  [Citicorp Global Information Network (CGIN), C...
# 491                      [eBay, Inc (EBAY), eBay, Inc]
# 492                                                 []
# 493                 [WebMD, Inc. (WEBMD), WebMD, Inc.]
# 495  [Webair Internet Development Company Inc. (WAI...
# 497      [Liquid Web, L.L.C (LQWB), Liquid Web, L.L.C]
# 498                                                 []
# 499  [Automatic Data Processing, Inc. (ADPES), Auto...
#
#                                                  Email  numOrg  numEmail   CDN
# 2                                             [fb.com]       2         1  None
# 3    [ns.chinanet.cn.net', ns.chinanet.cn.net, bjte...       0         3  None
# 4                      [wikimedia.org', wikimedia.org]       2         2  None
# 5                    [chinaunicom.cn', chinaunicom.cn]       0         2  None
# 6                    [yahoo-inc.com, cc.yahoo-inc.com]       2         2  None
# 8    [apnic.net, cnnic.cn', cnnic.cn, alibaba-inc.c...       0         6  None
# 10   [apnic.net, cnnic.cn', cnnic.cn, alibaba-inc.c...       0         6  None
# 12                                       [twitter.com]       2         1  None
# 13                     [microsoft.com., microsoft.com]       2         2  None
# 14   [chinaunicom.cn', chinaunicom.cn, publicf.bta....       0         3  None
# 15               [cnnic.cn', cnnic.cn, chinaunicom.cn]       0         3  None
# 16                 [yandex.ru', yandex.net, yandex.ru]       0         3  None
# 19                           [hgc.com.hk', hgc.com.hk]       0         2  None
# 20   [chinaunicom.cn', chinaunicom.cn, publicf.bta....       0         3  None
# 21   [ns.chinanet.cn.net', bjtelecom.net, ns.chinan...       0         3  None
# 22                       [sifycorp.com', sifycorp.com]       0         2  None
# 25                                      [linkedin.com]       2         1  None
# 28           [nic.ad.jp', mail.yahoo.co.jp, nic.ad.jp]       0         3  None
# 29                     [microsoft.com., microsoft.com]       2         2  None
# 30                     [microsoft.com., microsoft.com]       2         2  None
# 32   [apnic.net, cnnic.cn', cnnic.cn, alibaba-inc.c...       0         5  None
# 33                      [vk.com', vk.com, corp.vk.com]       0         3  None
# 36   [corp.mail.ru', corp.mail.ru, corp.mail.ru e-m...       0         3  None
# 38                       [sifycorp.com', sifycorp.com]       0         2  None
# 41   [cnnic.cn', cnnic.cn, alibaba-inc.com, list.al...       0         4  None
# 42                     [microsoft.com., microsoft.com]       2         2  None
# 45                          [ripe.net, softlayer.com']       2         2  None
# 46                                       [twitter.com]       2         1  None
# 47                                          [ebay.com]       2         1  None
# 50              [nic.or.kr', nic.or.kr, navercorp.com]       0         3  None
# ..                                                 ...     ...       ...   ...
# 446                                     [afranet.com']       0         1  None
# 450                [idnic.net', top.net.id, idnic.net]       0         3  None
# 451                                   [investing.com']       0         1  None
# 452                          [proxad.net', proxad.net]       0         2  None
# 453   [yahoo.com', yahoo.com, oath.com, yahoo-inc.com]       2         4  None
# 457                [yandex.ru', yandex.net, yandex.ru]       0         3  None
# 458                                       [itciti.ru']       0         1  None
# 460                   [nic.ad.jp', ntt.net, nic.ad.jp]       0         3  None
# 461                                    [cogentco.com']       3         1  None
# 463                                        [bitly.com]       2         1  None
# 464                                         [nike.com]       2         1  None
# 465                     [bloomberg.com, bloomberg.net]       2         2  None
# 466                                    [lightower.com]       2         1  None
# 467                [italiaonline.it', italiaonline.it]       2         2  None
# 468                 [cnnic.cn', cnnic.cn, tencent.com]       0         3  None
# 470                                 [surveymonkey.com]       2         1  None
# 474                [duodecadits.com', duodecadits.com]       0         2  None
# 475                                      [gannett.com]       2         1  None
# 477                            [seznam.cz', seznam.cz]       0         2  None
# 482           [nic.or.kr', nic.or.kr, skbroadband.com]       0         3  None
# 486                                         [ieee.org]       2         1  None
# 488                    [cnnic.cn', cnnic.cn, uclud.cn]       0         3  None
# 490                       [citi.com, cto.citicorp.com]       2         2  None
# 491                                         [ebay.com]       2         1  None
# 492                       [as5577.net', webzilla.com"]       0         2  None
# 493                                        [webmd.net]       2         1  None
# 495                                       [webair.com]       2         1  None
# 497                                    [liquidweb.com]       2         1  None
# 498                        [merdeka.com', merdeka.com]       0         2  None
# 499                                          [adp.com]       2         1  None
#
# [246 rows x 9 columns]

# %%
#sites_cdn.to_pickle('output/df_IP_ASN_CDN.pkl')
# Out:
#      rank              site               IP     ASN  \
# 0       1        google.com    216.58.221.46   15169
# 1       2       youtube.com   172.217.167.46   15169
# 2       3      facebook.com    157.240.25.35   32934
# 3       4         baidu.com   220.181.57.216   23724
# 4       5     wikipedia.org  103.102.166.224   14907
# 5       6            qq.com    111.161.64.40    4837
# 6       7         yahoo.com   98.138.219.232   36646
# 7       8        amazon.com  205.251.242.103   16509
# 8       9        taobao.com   140.205.94.189   37963
# 9      10        reddit.com  151.101.129.140   54113
# 10     11         tmall.com   140.205.94.193   37963
# 11     12      google.co.in    172.217.161.3   15169
# 12     13       twitter.com   104.244.42.129   13414
# 13     14          live.com   204.79.197.212    8068
# 14     15          sohu.com   123.125.116.28    4808
# 15     16            jd.com   120.52.148.118  133119
# 16     17         yandex.ru     5.255.255.55   13238
# 17     18      google.co.jp  172.217.166.227   15169
# 18     19     instagram.com     52.21.80.141   14618
# 19     20         weibo.com   114.134.80.162    9304
# 20     21       sina.com.cn   202.108.33.107    4808
# 21     22            360.cn    36.110.213.49   23724
# 22     23   login.tmall.com   223.30.211.253    9583
# 23     24      blogspot.com    172.217.161.9   15169
# 24     25     google.com.hk    216.58.221.35   15169
# 25     26      linkedin.com    108.174.10.10   14413
# 26     27       netflix.com     52.19.56.133   16509
# 27     28     google.com.br   172.217.167.35   15169
# 28     29       yahoo.co.jp    182.22.59.229   23816
# 29     30        office.com      52.108.36.3    8075
# ..    ...               ...              ...     ...
# 469   470          egy.best    104.25.237.22   13335
# 470   471  surveymonkey.com     64.191.16.50   18915
# 471   472   playstation.com  209.200.152.198   32787
# 472   473          9gag.com   151.101.66.133   54113
# 473   474     google.com.kw  172.217.166.227   15169
# 474   475     crptentry.com     93.93.53.190   34655
# 475   476      usatoday.com   159.54.242.176   21735
# 476   477      theverge.com     151.101.1.52   54113
# 477   478         seznam.cz      77.75.79.39   43037
# 478   479          rarbg.to   185.37.100.122  200097
# 479   480        rediff.com     23.67.216.77   16625
# 480   481           grid.id     52.76.113.15   38895
# 481   482        kooora.com   107.154.103.19   19551
# 482   483      dcinside.com    221.143.22.47    9318
# 483   484      kissanime.ru     104.20.27.43   13335
# 485   486       mawdoo3.com   151.101.66.202   54113
# 486   487          ieee.org   140.98.193.152   13462
# 487   488       android.com  172.217.166.196   15169
# 488   489         smzdm.com    106.75.63.226    4808
# 489   490      ilovepdf.com      104.20.0.94   13335
# 490   491          citi.com   192.193.218.80   32287
# 491   492       ebay.com.au    66.211.185.77   11643
# 492   493    digitaldsp.com   188.42.162.140   35415
# 493   494         webmd.com    208.93.170.15   46244
# 494   495          oath.com     74.6.136.153   26101
# 495   496    jf71qh5v14.com  198.134.112.244   27257
# 496   497          souq.com   34.254.103.253   16509
# 497   498    biobiochile.cl      67.43.7.192   32244
# 498   499       merdeka.com       103.6.0.15   58497
# 499   500           adp.com    170.146.93.56   14299
#
#                                                    Org  \
# 0                                  [Google LLC (GOGL)]
# 1                                  [Google LLC (GOGL)]
# 2                           [Facebook, Inc. (THEFA-3)]
# 3                                                   []
# 4                                        [ORG-WFI1-AP]
# 5                                                   []
# 6                                 [Yahoo! Inc. (YHOO)]
# 7                        [Amazon.com, Inc. (AMAZON-4)]
# 8                                                   []
# 9         [Fastly (SKYCA-3), Administered by RIPE NCC]
# 10                                                  []
# 11                                 [Google LLC (GOGL)]
# 12                              [Twitter Inc. (TWITT)]
# 13                      [Microsoft Corporation (MSFT)]
# 14                                                  []
# 15                                                  []
# 16                                          [RIPE NCC]
# 17                                 [Google LLC (GOGL)]
# 18                [Amazon Technologies Inc. (AT-88-Z)]
# 19                                                  []
# 20                                                  []
# 21                                                  []
# 22                                                  []
# 23                                 [Google LLC (GOGL)]
# 24                                 [Google LLC (GOGL)]
# 25                    [LinkedIn Corporation (LINKE-1)]
# 26   [Amazon Data Services Ireland Limited (ADSIL-1...
# 27                                 [Google LLC (GOGL)]
# 28                                                  []
# 29                      [Microsoft Corporation (MSFT)]
# ..                                                 ...
# 469                       [Cloudflare, Inc. (CLOUD14)]
# 470                      [SurveyMonkey Inc. (SURVE-7)]
# 471               [Akamai Technologies, Inc. (AKAMAI)]
# 472       [Fastly (SKYCA-3), Administered by RIPE NCC]
# 473                                [Google LLC (GOGL)]
# 474                                         [RIPE NCC]
# 475  [Gannett Satellite Information Network, LLC. (...
# 476       [Fastly (SKYCA-3), Administered by RIPE NCC]
# 477                                         [RIPE NCC]
# 478                         [RIPE NCC, ORG-SAAA2-RIPE]
# 479               [Akamai Technologies, Inc. (AKAMAI)]
# 480               [Amazon Technologies Inc. (AT-88-Z)]
# 481                          [Incapsula Inc (INCAP-5)]
# 482                                                 []
# 483                       [Cloudflare, Inc. (CLOUD14)]
# 485       [Fastly (SKYCA-3), Administered by RIPE NCC]
# 486  [Institute of Electrical and Electronics Engin...
# 487                                [Google LLC (GOGL)]
# 488                                                 []
# 489                       [Cloudflare, Inc. (CLOUD14)]
# 490       [Citicorp Global Information Network (CGIN)]
# 491                                 [eBay, Inc (EBAY)]
# 492                         [Administered by RIPE NCC]
# 493                              [WebMD, Inc. (WEBMD)]
# 494                       [Inktomi Corporation (INKT)]
# 495  [Webair Internet Development Company Inc. (WAIR)]
# 496  [Amazon Data Services Ireland Limited (ADSIL-1...
# 497                         [Liquid Web, L.L.C (LQWB)]
# 498                                                 []
# 499          [Automatic Data Processing, Inc. (ADPES)]
#
#                                                OrgName  \
# 0                                         [Google LLC]
# 1                                         [Google LLC]
# 2                                     [Facebook, Inc.]
# 3                                                   []
# 4                         [Wikimedia Foundation, Inc.]
# 5                                                   []
# 6                                        [Yahoo! Inc.]
# 7                                   [Amazon.com, Inc.]
# 8            [Asia Pacific Network Information Centre]
# 9                                             [Fastly]
# 10           [Asia Pacific Network Information Centre]
# 11                                        [Google LLC]
# 12                                      [Twitter Inc.]
# 13                             [Microsoft Corporation]
# 14                                                  []
# 15                                                  []
# 16                                                  []
# 17                                        [Google LLC]
# 18                          [Amazon Technologies Inc.]
# 19                                                  []
# 20                                                  []
# 21                                                  []
# 22                                                  []
# 23                                        [Google LLC]
# 24                                        [Google LLC]
# 25                              [LinkedIn Corporation]
# 26   [Amazon Technologies Inc., Amazon Data Service...
# 27                                        [Google LLC]
# 28                                                  []
# 29                             [Microsoft Corporation]
# ..                                                 ...
# 469                                 [Cloudflare, Inc.]
# 470                                [SurveyMonkey Inc.]
# 471                        [Akamai Technologies, Inc.]
# 472                                           [Fastly]
# 473                                       [Google LLC]
# 474                                                 []
# 475      [Gannett Satellite Information Network, LLC.]
# 476                                           [Fastly]
# 477                                                 []
# 478                      [S A and A stroi proekt EOOD]
# 479                        [Akamai Technologies, Inc.]
# 480                         [Amazon Technologies Inc.]
# 481                                    [Incapsula Inc]
# 482                                                 []
# 483                                 [Cloudflare, Inc.]
# 485                                           [Fastly]
# 486  [Institute of Electrical and Electronics Engin...
# 487                                       [Google LLC]
# 488                                                 []
# 489                                 [Cloudflare, Inc.]
# 490              [Citicorp Global Information Network]
# 491                                        [eBay, Inc]
# 492                                                 []
# 493                                      [WebMD, Inc.]
# 494                              [Inktomi Corporation]
# 495         [Webair Internet Development Company Inc.]
# 496  [Amazon Technologies Inc., Amazon Data Service...
# 497                                [Liquid Web, L.L.C]
# 498                                                 []
# 499                  [Automatic Data Processing, Inc.]
#
#                                            EmailServer
# 0                                         [google.com]
# 1                                         [google.com]
# 2                                       [facebook.com]
# 3                  [ns.chinanet.cn.net, bjtelecom.net]
# 4                                      [wikimedia.org]
# 5                                     [chinaunicom.cn]
# 6                    [cc.yahoo-inc.com, yahoo-inc.com]
# 7                          [amazonaws.com, amazon.com]
# 8    [alibaba-inc.com, cnnic.cn, aliyun-inc.com, li...
# 9                                         [fastly.com]
# 10   [alibaba-inc.com, cnnic.cn, aliyun-inc.com, li...
# 11                                        [google.com]
# 12                                       [twitter.com]
# 13                                     [microsoft.com]
# 14                [chinaunicom.cn, publicf.bta.net.cn]
# 15                          [cnnic.cn, chinaunicom.cn]
# 16                                                  []
# 17                                        [google.com]
# 18                         [amazonaws.com, amazon.com]
# 19                                        [hgc.com.hk]
# 20                [chinaunicom.cn, publicf.bta.net.cn]
# 21                 [ns.chinanet.cn.net, bjtelecom.net]
# 22                                      [sifycorp.com]
# 23                                        [google.com]
# 24                                        [google.com]
# 25                         [zaidali.com, linkedin.com]
# 26                         [amazonaws.com, amazon.com]
# 27                                        [google.com]
# 28                                         [nic.ad.jp]
# 29                                     [microsoft.com]
# ..                                                 ...
# 469                                   [cloudflare.com]
# 470                                 [surveymonkey.com]
# 471                                       [akamai.com]
# 472                                       [fastly.com]
# 473                                       [google.com]
# 474                                                 []
# 475                                      [gannett.com]
# 476                                       [fastly.com]
# 477                                                 []
# 478                                                 []
# 479                                       [akamai.com]
# 480                        [amazonaws.com, amazon.com]
# 481                       [imperva.com, incapsula.com]
# 482                       [nic.or.kr, skbroadband.com]
# 483                                   [cloudflare.com]
# 485                                       [fastly.com]
# 486                                         [ieee.org]
# 487                                       [google.com]
# 488                               [cnnic.cn, uclud.cn]
# 489                                   [cloudflare.com]
# 490                       [citi.com, cto.citicorp.com]
# 491                                         [ebay.com]
# 492                                                 []
# 493                                        [webmd.net]
# 494                  [cc.yahoo-inc.com, yahoo-inc.com]
# 495                                       [webair.com]
# 496                        [amazonaws.com, amazon.com]
# 497                                    [liquidweb.com]
# 498                                      [merdeka.com]
# 499                                          [adp.com]
#
# [493 rows x 7 columns]

# %%
CDN_names
# Out:
# ['AAPT',
#  'ARA Networks',
#  'AT&T',
#  'AT&T Inc.',
#  'Akamai',
#  'Akamai Technologies',
#  'Alibaba',
#  'Allot Communications',
#  'Amazon',
#  'Amazon CloudFront',
#  'Aryaka',
#  'Azure CDN',
#  'BT',
#  'BT Group',
#  'BTI Systems',
#  'Bell',
#  'Bell Canada',
#  'BelugaCDN',
#  'Bharti Airtel',
#  'BitTorrent, Inc.',
#  'Blue Coat',
#  'BootstrapCDN',
#  'Broadmedia',
#  'Broadpeak',
#  'CDN77',
#  'CDNetworks',
#  'CacheFly',
#  'Cedexis',
#  'CenterServ',
#  'CenturyLink',
#  'China Telecom',
#  'ChinaCache',
#  'ChinaNetCenter',
#  'Cisco',
#  'Cloudflare',
#  'Comcast',
#  'Concentric',
#  'Concurrent',
#  'Conversant',
#  'Conviva',
#  'Coral Content Distribution Network',
#  'Cotendo',
#  'Deutsche Telekom',
#  'EdgeCast Networks',
#  'Edgeware',
#  'Ericsson',
#  'Fastly',
#  'Fortinet',
#  'Google Cloud',
#  'HP Cloud Services',
#  'HiNet',
#  'Hibernia Networks',
#  'Highwinds',
#  'Highwinds Network Group',
#  'Hola',
#  'Huawei',
#  'Incapsula',
#  'IneoQuest',
#  'Instart',
#  'Instart Logic',
#  'Interferex',
#  'Internap',
#  'Interoute',
#  'JSDelivr',
#  'Jetstream',
#  'Juniper ',
#  'KPN',
#  'KT',
#  'Korea Telecom',
#  'LeaseWeb',
#  'Level 3',
#  'Level 3 Communications',
#  'Limelight Networks',
#  'Megafon',
#  'MetaCDN',
#  'Microsoft Azure',
#  'MileWEB',
#  'Mirror Image',
#  'NACEVI',
#  'NTT',
#  'NTT Communications',
#  'NaviSite',
#  'Ngenix',
#  'Nice People At Work',
#  'Nokia',
#  'OVH',
#  'OnApp',
#  'Ono',
#  'Orange',
#  'PCCW',
#  'Pacnet',
#  'Pando Networks',
#  'PeerApp',
#  'Qualitynet',
#  'Qwilt',
#  'Rackspace Cloud Files',
#  'Radware',
#  'Rawflow',
#  'Reliance Globalcom',
#  'RevAMP',
#  'SFR',
#  'SK Broadband',
#  'SKY',
#  'SSIMWave',
#  'STC',
#  'SingTel',
#  'Solbox',
#  'Spark New Zealand',
#  'Speedera Networks',
#  'StackPath',
#  'StreamZilla',
#  'Swarmify',
#  'Swiftserve',
#  'Swisscom',
#  'Tata Communications',
#  'Telcom Italia',
#  'Telecom Argentina',
#  'Telecom Italia',
#  'Telecom Italia Sparkle',
#  'Telecom Malaysia',
#  'Telefonica',
#  'Telenor',
#  'TeliaSonera',
#  'Telin',
#  'Telstra',
#  'Telus',
#  'Touchstream',
#  'Turk Telekom',
#  'Varnish',
#  'Verizon',
#  'Vidscale',
#  'Wangsu Science & Technology',
#  'Webscale',
#  'Yottaa']
